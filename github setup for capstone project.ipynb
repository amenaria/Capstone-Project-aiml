# %% [markdown]
# # Objective
# This notebook has been setup to push the capstone project code to gitlab and ensure the latest working version is maintained in the GIT repository safely.
#
# ## When to run this notebook
# This notebook has to be run ONLY when ALL of the below conditions are met.
#
# 1. A new code block / functionality / feature is developed and added to the main project notebook named "Capstone Project - Computer Vision - Pneumonia Detection Challenge.ipynb"
# 2. The same has been tested / validated by another member in the team and is found to be working as expected without breaking any working functionality.
#
# ## When NOT to run this notebook
# Don't run this notebook in ANY of the below situations
# 1. When you added a new code block
# 2. When you modified an existing code block
# 3. When your code is pending peer review and validation

# %%
# First Mount your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Declare the project path as per your own drive location 
# OR save the ipynb files as per below directory structure in your google drive
# project_path = '/content/gdrive/MyDrive/Colab Notebooks/CS Project/'
project_path = '/content/drive/MyDrive/Colab Notebooks/Capstone Project/'
print(project_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/Capstone Project/

# %%
import os
os.chdir(project_path)
print(os.getcwd())
# !git init
# Out:
# /content/drive/MyDrive/Colab Notebooks/Capstone Project
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Capstone Project/.git/

# %%
# Authentication for your github account
import getpass
# User will be prompted to enter the github username, password and email id
github_username = input('Username: ')
github_password = getpass.getpass( prompt='Password: ', stream=None) 
github_email = input('Github email: ')

github_repo_name = 'Capstone-Project-aiml'  # Do not change
# Out:
# Username: amenaria
# Password: ··········
# Github email: arpit536@gmail.com

# %%
# !git remote remove origin
# !git remote add origin https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git

# %%
# !git config --global user.email '{github_email}'
# !git config --global user.name '{github_username}'

# %%
# !git pull origin master
# Out:
# From https://github.com/amenaria/Capstone-Project-aiml
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# Already up to date.

# %%
# Now add the files in the current directory for commit and make your commit
# !git add .

# Add comments to what you have added/modified to the existing code
comment = 'Updating SSD model final notebook'  # Change it to indicate the changes you have made
# !git commit -m comment
# Out:
# [master 9306cc7] comment
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Arpit's 4th Copy of Capstone Project - Computer Vision - Pneumonia Detection Challenge - using SSD.ipynb (66%)

# %%
# Finally push to the github

# !git push origin master
# Out:
# Counting objects: 13, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 2.49 MiB | 3.95 MiB/s, done.
# Total 13 (delta 9), reused 0 (delta 0)
# remote: Resolving deltas: 100% (9/9), completed with 3 local objects.
# To https://github.com/amenaria/Capstone-Project-aiml.git
#    bf03911..9306cc7  master -> master
